# %%
a = 42
print(a)
a = "Oh no!"
print(a)

# %%
a = 42
print(type(a))
print(a)
a = "Oh no!"
print(type(a))
print(a)

# %%
a = 42
b = "Hello"

# %%
a, b

# %%
a + b

# %%
str(a) + b

# %%
a

# %%
b

# %%
c = str(a) + b
c

# %%
d = 101

# %%
id(d)

# %%
d

# %%
d = "Different"

# %%
id(d)

# %%
d

# %%
d = print

# %%
type(d)

# %%
d("Hello World")

# %%
a, b

# %%
temp = a
a = b
b = temp

# %%
a, b

# %%
a, b = b, a

# %%
a, b

# %%
_next = "Anything"
__previous__ = "more of the same"

# %%
_next # wonder next

# %%
__previous__ # dunder previous (Magic methods)

# %%
title = "So long an thanks for all the fish."

# %%
"thank" in title

# %%
"cricket" in title

# %%
True, False

# %%
true = 42

# %%
true

# %%
True = 42

# %%
bool(True)

# %%
bool(False)

# %%
bool(0)

# %%
bool(1)

# %%
bool(-42)

# %%
bool(0.00000000000000000000000000000000000000000000001)

# %%
bool(0.0)

# %%
bool("Hello")

# %%
bool("")

# %%
bool("      ")

# %%
len("      ")

# %%
bool(print)

# %%
a, b, c, d

# %%
if a != 0:
    print("Non zero value of a.")

# %%
if a:
    print("Non zero value of a.")

# %%
a = ""

if a:
    print("Non zero value of a.")
else:
    print("That's false.")
    print("Is this OK?")

# %% [raw]
# int a = 0;
#
# if (a != 0) {
#     cout << "Non zero value of a.\n";
#     cout << "Cool, eh?\n";
# } else {
#     cout << "Cool, eh?";
# };

# %%
b = 500

if not b:
    print("b is false")
elif b < 100:
    print("b is between 0 and 101")
elif b < 200:
    print("b is between 101 and 201")
else:
    print("b is really big")

# %%
title2 = "Life, the Universe, and Everything"

# %%
title2

# %%
len(title2)

# %%
letters = "aeiou"
print(letters[-2])

# %%
num = 42
num += 1
num

# %%
ecount = 0
lettercount = 0
while lettercount < len(title2)-1:
    if title2[lettercount] == "e":
        ecount = ecount+1  # Python does not support ++
    lettercount = lettercount+1
print("The number of e's is:", ecount)

# %%
title2

# %%
ecount = 0
for ch in title2:
    if ch == " ":
        ecount = ecount+1
print("The number of spaces is:", ecount)

# %%
title2

# %%
type(title2)

# %%
print(dir(title2))

# %%
title2.upper()

# %%
title2

# %%
t = title2.upper()

# %%
t

# %%
title2.capitalize()

# %%
title2.title()

# %%
print(dir(title2))

# %%
title2.count("e")

# %%
title2

# %%
title2.endswith("ing")

# %%
title2.endswith("ing.")

# %%
title2.replace(" ", "***")

# %%
title2

# %%
title2.replace(" ", "***").upper()

# %%
title2.split()

# %%
what = title2.split()

# %%
what

# %%
type(what)

# %%
len(what)

# %%
title2

# %%
title2.split("e")

# %%
title2

# %%
title2.strip()

# %%
title2.strip("ing")

# %%
title2.strip("gni")

# %%
title2.strip("gniL")

# %%
title2.lstrip("gniL")

# %%
title2.rstrip("gniL")

# %%
print(dir(title2))

# %%
title2.find("and")

# %%
title2

# %%
title2[20]

# %%
title2[21]

# %%
title2[22]

# %%
title2.find("Life")

# %%
title2.find("dfddafd")

# %%
title2.index("and")

# %%
title2.index("daffafaf")

# %%
title2.translate?

# %%
title2.strip?

# %%
type(None)

# %%
title2[15]

# %%
title2

# %%
title2[15] = "R"
